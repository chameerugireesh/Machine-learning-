# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=[['apple',10,240],['orange',15,150],['grapes',14,80],['pineapple',10, 70]]

# %%
df2 =pd.DataFrame(data, columns = ['fruit_name','quantity','unit_price'])
df2
# Out:
#   fruit_name  quantity  unit_price
# 0      apple        10         240
# 1     orange        15         150
# 2     grapes        14          80
# 3  pineapple        10          70

# %%
df2.describe()
# Out:
#         quantity  unit_price
# count   4.000000    4.000000
# mean   12.250000  135.000000
# std     2.629956   78.528127
# min    10.000000   70.000000
# 25%    10.000000   77.500000
# 50%    12.000000  115.000000
# 75%    14.250000  172.500000
# max    15.000000  240.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   fruit_name  4 non-null      object
#  1   quantity    4 non-null      int64
#  2   unit_price  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
data={'fruit_name':['apple','orange','grapes','pineapple'],'quantity':[10,15,14,10],'unit_price':[240,150,80,70]}
df3=pd.DataFrame(data,index=['f1','f2','f3','f4'])
df3
# Out:
#    fruit_name  quantity  unit_price
# f1      apple        10         240
# f2     orange        15         150
# f3     grapes        14          80
# f4  pineapple        10          70

# %%
data=[{'fruit_name':'apple','quantity':10,'unit_price':240},{'fruit_name':'orange','quantity':15,'unit_price':150},{'fruit_name':'grapes','quantity':14,'unit_price':80}, {'fruit_name':'pine apple','quantity':10,'unit_price':70}]
df4 = pd.DataFrame(data)

# %%
df4
# Out:
#    fruit_name  quantity  unit_price
# 0       apple        10         240
# 1      orange        15         150
# 2      grapes        14          80
# 3  pine apple        10          70

# %%
row={'fruit_name':'litchy','quantity':10,'unit_price':80}
df4=df.append(row,ignore_index=True)
df4
# Out:
#   fruit_name  quantity  unit_price
# 0      apple        10         240
# 1     orange        15         150
# 2     grapes        14          80
# 3  pineapple        10          70
# 4     litchy        10          80

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df3.loc[len(df4.index)] =['cherry',5,500]
df4
# Out:
#   fruit_name  quantity  unit_price
# 0      apple        10         240
# 1     orange        15         150
# 2     grapes        14          80
# 3  pineapple        10          70
# 4     litchy        10          80

# %%
data=[{'fruit_name':'mango','quantity':13,'unit_price':140},{'fruit_name':'strawberry','quantity':8,'unit_price':250}]
df5 =pd.DataFrame(data)

# %%
df4=pd.concat([df4,df5],ignore_index=True)
df4
# Out:
#    fruit_name  quantity  unit_price
# 0       apple        10         240
# 1      orange        15         150
# 2      grapes        14          80
# 3   pineapple        10          70
# 4      litchy        10          80
# 5       mango        13         140
# 6  strawberry         8         250

# %%
df4['Total_price']= df4['quantity']* df4['unit_price']
df4
# Out:
#    fruit_name  quantity  unit_price  Total_price
# 0       apple        10         240         2400
# 1      orange        15         150         2250
# 2      grapes        14          80         1120
# 3   pineapple        10          70          700
# 4      litchy        10          80          800
# 5       mango        13         140         1820
# 6  strawberry         8         250         2000

# %%
df4.columns =['fruit','qty','upprice','Totproce']
df4
# Out:
#         fruit  qty  upprice  Totproce
# 0       apple   10      240      2400
# 1      orange   15      150      2250
# 2      grapes   14       80      1120
# 3   pineapple   10       70       700
# 4      litchy   10       80       800
# 5       mango   13      140      1820
# 6  strawberry    8      250      2000

# %%
df4 =df4.rename({'qty':'quantity','uprice':'Unitprice'},axis='columns')
df4
# Out:
#         fruit  quantity  upprice  Totproce
# 0       apple        10      240      2400
# 1      orange        15      150      2250
# 2      grapes        14       80      1120
# 3   pineapple        10       70       700
# 4      litchy        10       80       800
# 5       mango        13      140      1820
# 6  strawberry         8      250      2000

# %%
df4.index =['f1','f2','f4','f3','f8','f6','f7']
df4
# Out:
#          fruit  quantity  upprice  Totproce
# f1       apple        10      240      2400
# f2      orange        15      150      2250
# f4      grapes        14       80      1120
# f3   pineapple        10       70       700
# f8      litchy        10       80       800
# f6       mango        13      140      1820
# f7  strawberry         8      250      2000

# %%
df4=df4.sort_index()
df4
# Out:
#          fruit  quantity  upprice  Totproce
# f1       apple        10      240      2400
# f2      orange        15      150      2250
# f3   pineapple        10       70       700
# f4      grapes        14       80      1120
# f6       mango        13      140      1820
# f7  strawberry         8      250      2000
# f8      litchy        10       80       800

# %%
df4 = df4.sort_index(ascending=False)
df4
# Out:
#          fruit  quantity  upprice  Totproce
# f8      litchy        10       80       800
# f7  strawberry         8      250      2000
# f6       mango        13      140      1820
# f4      grapes        14       80      1120
# f3   pineapple        10       70       700
# f2      orange        15      150      2250
# f1       apple        10      240      2400

# %%
df4 = df4.sort_index(axis=1)
df4
# Out:
#     Totproce       fruit  quantity  upprice
# f8       800      litchy        10       80
# f7      2000  strawberry         8      250
# f6      1820       mango        13      140
# f4      1120      grapes        14       80
# f3       700   pineapple        10       70
# f2      2250      orange        15      150
# f1      2400       apple        10      240

# %%
df4=df4.sort_index(ascending=False,axis=1)
df4
# Out:
#     upprice  quantity       fruit  Totproce
# f8       80        10      litchy       800
# f7      250         8  strawberry      2000
# f6      140        13       mango      1820
# f4       80        14      grapes      1120
# f3       70        10   pineapple       700
# f2      150        15      orange      2250
# f1      240        10       apple      2400

# %%
phone_company1= pd.Series(['apple','samsung','lenova','dell','acer'],name ='Brand')

phone_price= pd.Series([100000,35000,40000,42000,28000],name='price')
print(phone_company1)
print(phone_price)
# Out:
# 0      apple
# 1    samsung
# 2     lenova
# 3       dell
# 4       acer
# Name: Brand, dtype: object
# 0    100000
# 1     35000
# 2     40000
# 3     42000
# 4     28000
# Name: price, dtype: int64

# %%
df6 =pd.merge(phone_company1,phone_price,left_index=True,right_index=True)
df6
# Out:
#      Brand   price
# 0    apple  100000
# 1  samsung   35000
# 2   lenova   40000
# 3     dell   42000
# 4     acer   28000

# %%
df7=phone_company1.to_frame()
df7
# Out:
#      Brand
# 0    apple
# 1  samsung
# 2   lenova
# 3     dell
# 4     acer

# %%
df8=phone_company1.to_frame().reset_index()
df8
# Out:
#    index    Brand
# 0      0    apple
# 1      1  samsung
# 2      2   lenova
# 3      3     dell
# 4      4     acer

# %% [markdown]
# # Iris

# %%
df=pd.read_csv("C:/Users/ch gireesh/OneDrive/Documents/data science/Data set/Iris.csv")

# %%
df = df.rename(columns={'sepal_length': 'new_sepal_length', 'sepal_width': 'new_sepal_width', 'petal_length': 'new_petal_length', 'petal_width': 'new_petal_width', 'class': 'new_class'})
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 23    24            5.1           3.3            1.7           0.5
# 80    81            5.5           2.4            3.8           1.1
# 137  138            6.4           3.1            5.5           1.8
# 141  142            6.9           3.1            5.1           2.3
# 109  110            7.2           3.6            6.1           2.5
#
#              Species
# 23       Iris-setosa
# 80   Iris-versicolor
# 137   Iris-virginica
# 141   Iris-virginica
# 109   Iris-virginica

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.shape
# Out:
# (150, 6)

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df['SepalLengthCm'].dtype
# Out:
# dtype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df['SepalLengthCm'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-540400c269df> in <module>
# ----> 1 df['class'].value_counts()
#
# ...

# %%
df['cla'].unique()
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.4, 4.8, 4.3, 5.8, 5.7, 5.2, 5.5,
#        4.5, 5.3, 7. , 6.4, 6.9, 6.5, 6.3, 6.6, 5.9, 6. , 6.1, 5.6, 6.7,
#        6.2, 6.8, 7.1, 7.6, 7.3, 7.2, 7.7, 7.4, 7.9])

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
Data_frame = pd.DataFrame({
    'brand':['yum yum','cup','cup','pack','pack'],
    'rating': [4,4,3.5,15,5]
})

# %%
Data_frame
# Out:
#      brand  rating
# 0  yum yum     4.0
# 1      cup     4.0
# 2      cup     3.5
# 3     pack    15.0
# 4     pack     5.0

# %%
Data_frame.duplicated().sum()
# Out:
# 0

# %%
df[2:10]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df.loc[5]
# Out:
# Id                         6
# SepalLengthCm            5.4
# SepalWidthCm             3.9
# PetalLengthCm            1.7
# PetalWidthCm             0.4
# Species          Iris-setosa
# Name: 5, dtype: object

# %%
df.iloc[5]
# Out:
# Id                         6
# SepalLengthCm            5.4
# SepalWidthCm             3.9
# PetalLengthCm            1.7
# PetalWidthCm             0.4
# Species          Iris-setosa
# Name: 5, dtype: object

# %%
df3
# Out:
#    fruit_name  quantity  unit_price
# f1      apple        10         240
# f2     orange        15         150
# f3     grapes        14          80
# f4  pineapple        10          70
# 5      cherry         5         500

# %%
df3.loc['f1']
# Out:
# fruit_name    apple
# quantity         10
# unit_price      240
# Name: f1, dtype: object

# %%
df['PetalLengthCm']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PetalLengthCm, Length: 150, dtype: float64

# %%
df.iloc[5:10]['PetalLengthCm']
# Out:
# 5    1.7
# 6    1.4
# 7    1.5
# 8    1.4
# 9    1.5
# Name: PetalLengthCm, dtype: float64

# %%
df.loc[5:10]['PetalLengthCm']
# Out:
# 5     1.7
# 6     1.4
# 7     1.5
# 8     1.4
# 9     1.5
# 10    1.5
# Name: PetalLengthCm, dtype: float64

# %%
df.loc[55:60, ['SepalWidthCm', 'PetalLengthCm']]
# Out:
#     SepalWidthCm  PetalLengthCm
# 55           2.8            4.5
# 56           3.3            4.7
# 57           2.4            3.3
# 58           2.9            4.6
# 59           2.7            3.9
# 60           2.0            3.5

# %%
print(df['PetalLengthCm'].sum())
print(df['PetalLengthCm'].mean())
print(df['PetalLengthCm'].median())
# Out:
# 563.8
# 3.7586666666666693
# 4.35
